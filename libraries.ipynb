# %%
import numpy as np

# %%
i = np.array([[1,0,0],[0,1,0],[0,0,1]])

# %%
print(i)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
a = np.array([[1,2,3],[3,2,1],[2,1,3]])

# %%
print(a)
# Out:
# [[1 2 3]
#  [3 2 1]
#  [2 1 3]]

# %%
np.dot(i,a)
# Out:
# array([[1, 2, 3],
#        [3, 2, 1],
#        [2, 1, 3]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 1000)
plt.plot(x, np.tan(x))
plt.ylim(-5,5)
# Out:
# (-5, 5)

# %%
import matplotlib.pyplot as plt
import csv

# %%
def read_file(filename):
    data = np.genfromtxt(filename, delimiter=",")
    x = data[:,0]
    y = data[:,1]
    return(x, y)

# %%
x, y  = read_file ("mbro-02.csv")

# %%
plt.plot(x,y, 'o-')
